# %% [markdown]
# *** data sensor:
# ** A. Nhóm nhiệt liệu than
# - LDA12080012000243: Độ ẩm than cấp lò
# - LDA12080012000228: Chất bốc
# - LDA12080012000227: Độ tro
# - LDA12080012000230: Nhiệt trị than trong lò
# - LDA11070012000630: Nhiệt trị (MJ/Mn3)
# - LDA12080012000238: Cỡ hạt 0-025
# - LDA12080012000237: Cỡ hạt 025-1
# - LDA12080012000232: Cỡ hạt 10-16
# - LDA12080012000236: Cỡ hạt 1-2
# - LDA12080012000235: Cỡ hạt 2-4
# - LDA12080012000234: Cỡ hạt 4-8
# - LDA12080012000233: Cỡ hạt 8-10
# - CM_A181AT0004_DACA_PV__Value: Độ ẩm online
# - LDA07060012000122: Độ ẩm
# - LDA07060012000156: 15um
# - LDA07060012000157: 20um
# - LDA07060012000158: 45um
# - LDA07060012000159: 50um
# - LDA07060012000160: 60um
# - LDA07060012000161: 70um
# - LDA07060012000162: 80um
# - LDA07060012000163: 100um
# - LDA07060012000164: 120um
# - LDA07060012000165: 130um
# - LDA07060012000166: 150um
# - CM_A181PT0013_DACA_PV__Value: Áp khí than
#
# ** B. Nhóm công suất và tiêu hao
# - B1_FT1151_DACA_PV__Value: Công suất lò hơi (tấn/h)
# - B2_FT1151_DACA_PV__Value: Công suất lò hơi 2 (tấn/h)
# - B1_FT1151_DIVA_OUT__Value: Mức tiêu hao trên 1 tấn hơi cao áp
# - B2_FT1151_DIVA_OUT__Value: Mức tiêu hao trên 1 tấn hơi cao áp
# - CM_A181_TIEUHAOCO_OUT__Value: Tiêu hao khí than/tấn AO(m3/tấn)
#
# ** C. Nhóm nhiệt độ
# - B1_TE1251_DACA_PV__Value: Nhiệt độ nước cấp (Độ C)
# - B1_Z_BEDT_DACA_PV__Value: Nhiệt độ buồng đốt (Độ C)
# - B2_TE1251_DACA_PV__Value: Nhiệt độ nước cấp (Độ C)
# - B2_Z_BEDT_DACA_PV__Value: Nhiệt độ buồng đốt (Độ C)
# - B1_TE1212_DACA_PV__Value: Nhiệt độ hơi quá nhiệt (Độ C)
# - B2_TE1212_DACA_PV__Value: Nhiệt độ hơi quá nhiệt (Độ C)
# - B1_TE1111_DACA_PV__Value: Nhiệt độ nháy đuôi lò TE1111 (Độ C)
# - B1_TE1112_DACA_PV__Value: Nhiệt độ nháy đuôi lò TE1112 (Độ C)
# - B2_TE1111_DACA_PV__Value: Nhiệt độ nháy đuôi lò TE1111 (Độ C)
# - B2_TE1112_DACA_PV__Value: Nhiệt độ nháy đuôi lò TE1112 (Độ C)
# - CM_A181TE0007_DACA_PV__Value: Nhiệt PO4
# - CM_A181TE0023_DACA_PV__Value: NHiệt độ khói thải
# - CM_A181_V19_COM_V19_IN_5_PV3__Value: Nhiệt độ (độ C)
#
# ** D. Nhóm áp suất
# - B1_PT1281_DACA_PV__Value: Áp lực hơi quá nhiệt (MPa)
# - B2_PT1281_DACA_PV__Value: Áp lực hơi quá nhiệt (MPa)
# - B1_PT1061_DACA_PV__Value: Áp lực Windbox PT1061 (kPa)
# - B1_PT1071_DACA_PV__Value: Áp lực Windbox PT1071 (kPa)
# - B2_PT1061_DACA_PV__Value: Áp lực Windbox PT1061 (kPa)
# - B2_PT1071_DACA_PV__Value: Áp lực Windbox PT1071 (kPa)
# - B1_PT1111_DACA_PV__Value: Áp lực tầng liệu PT1111 (Pa)
# - B1_PT1112_DACA_PV__Value: Áp lực tầng liệu PT1112 (Pa)
# - B2_PT1111_DACA_PV__Value: Áp lực tầng liệu PT1111 (Pa)
# - B2_PT1112_DACA_PV__Value: Áp lực tầng liệu PT1112 (Pa)
# - B1_PT1211_DACA_PV__Value: Áp lực đỉnh buồng đốt PT1211 (Pa)
# - B1_PT1212_DACA_PV__Value: Áp lực đỉnh buồng đốt PT1212 (Pa)
# - B2_PT1211_DACA_PV__Value: Áp lực đỉnh buồng đốt PT1211 (Pa)
# - B2_PT1212_DACA_PV__Value: Áp lực đỉnh buồng đốt PT1212 (Pa)
# - B1_PT1081_DACA_PV__Value: Áp lực hồi liệu PT1081 (kPa)
# - B1_PT1082_DACA_PV__Value: Áp lực hồi liệu PT1082 (kPa)
# - B1_PT1091_DACA_PV__Value: Áp lực hồi liệu PT1091 (kPa)
# - B1_PT1092_DACA_PV__Value: Áp lực hồi liệu PT1092 (kPa)
# - B2_PT1081_DACA_PV__Value: Áp lực hồi liệu PT1081 (kPa)
# - B2_PT1082_DACA_PV__Value: Áp lực hồi liệu PT1082 (kPa)
# - B2_PT1091_DACA_PV__Value: Áp lực hồi liệu PT1091 (kPa)
# - B2_PT1092_DACA_PV__Value: Áp lực hồi liệu PT1092 (kPa)
# - CM_A181PT0002_DACA_PV__Value: PO1P2
# - CM_A181PT0003_DACA_PV__Value: PO2P2
# - CM_A181PT0004_DACA_PV__Value: PO3P2
# - CM_A181PT0005_DACA_PV__Value: CO1P2
# - CM_A181PT0006_DACA_PV__Value: CO2P2
# - CM_A181PT0007_DACA_PV__Value: CO3P2
# - CM_A181PDT0002_DACA_PV__Value: PO4P
# - CM_A181PT0008_DACA_PV__Value: CO4P2
#
# ** E. Nhóm oxy và khói thải
# - B1_AT1011_DACA_PV__Value: Oxy đuôi lò AT1011 (%)
# - B1_AT1012_DACA_PV__Value: Oxy đuôi lò AT1012 (%)
# - B2_AT1011_DACA_PV__Value: Oxy đuôi lò AT1011 (%)
# - B2_AT1012_DACA_PV__Value: Oxy đuôi lò AT1012 (%)
# - CM_A181AT0001_DACA_PV__Value: Oxi dư (%)
#
# ** F. Nhóm van- quạt- điện- tần số
# - B1_TZ1131ZT_DACA_PV__Value: Độ mở van đầu hút quạt cấp 1 (%)
# - B1_AZ1011ZT_DACA_PV__Value: Độ mở van đầu hút quạt cấp 2 (%)
# - B2_TZ1131ZT_DACA_PV__Value: Độ mở van đầu hút quạt cấp 1 (%)
# - B2_AZ1011ZT_DACA_PV__Value: Độ mở van đầu hút quạt cấp 2 (%)
# - B1_S051AIT_DACA_PV__Value: Dòng điện làm việc quạt cấp 1 (A)
# - B1_S052AIT_DACA_PV__Value: Dòng điện làm việc quạt cấp 2 (A)
# - B1_S052AVFD_CRT_DACA_PV__Value: Dòng điện làm việc quạt gió cấp 2 (S052aVFD)
# - B1_S052AVFD_FB_DACA_PV__Value: Tần số VFD (Hz)
# - B2_S051AIT_DACA_PV__Value: Dòng điện làm việc quạt cấp 1 (A)
# - B2_S052AIT_DACA_PV__Value: Dòng điện làm việc quạt cấp 2 (A)
# - B2_S052AVFD_CRT_DACA_PV__Value: Dòng điện làm việc quạt gió cấp 2 (S052aVFD)
# - B2_S052AVFD_FB_DACA_PV__Value: Tần số VFD (Hz)
# - CM_A181S015BPGPV_DACA_PV__Value: Quạt ID
#
# ** G. Nhóm lưu lượng
# - CM_A181FT0010_DACA_PV__Value: Lưu lượng (m3/h)
# - CM_A181FT0001_DACA_PV__Value: Tốc độ AH cấp lò (t/h)

# %%
import pandas as pd

# File CSV
file_path = r"D:\LDA\DL\_DATA_CTCN__202512051330.csv"

# Các cột cần dùng
use_cols = [
    'LDA12080012000243' # Độ ẩm than cấp lò
]

# Đọc dữ liệu theo chunks để tránh lỗi bộ nhớ
chunks = []
for chunk in pd.read_csv(file_path, usecols=use_cols, chunksize=200_000):
    chunks.append(chunk)

df = pd.concat(chunks, ignore_index=True)

df['LDA12080012000243'].describe()
# Out:
# count    24099.000000
# mean         8.909465
# std          0.404156
# min          6.203190
# 25%          8.706516
# 50%          8.962189
# 75%          9.160561
# max         10.030828
# Name: LDA12080012000243, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.hist(df['LDA12080012000243'], bins=20)
plt.title("Histogram độ ẩm than")
plt.xlabel("Giá trị độ ẩm")
plt.ylabel("Tần suất")
plt.show()

# %% [markdown]
# ** ÁP LỨC HƠI QUÁ NHIỆT

# %%
use_cols = [
    "CronTime",
    "B1_PT1281_DACA_PV__Value",
    "B2_PT1281_DACA_PV__Value",
]
result = []

for chunk in pd.read_csv(
    r"D:\LDA\LDA---ML--RnD\ai\data\_DCS_Items__202512051333.csv",
    usecols=use_cols,
    chunksize=300_000,
):
    chunk["CronTime"] = pd.to_datetime(chunk["CronTime"])
    chunk = chunk.set_index("CronTime")
    resampled = chunk.resample("5min").mean()
    result.append(resampled)

df_5min = pd.concat(result)

df_5min
# Out:
#                      B2_PT1281_DACA_PV__Value  B1_PT1281_DACA_PV__Value
# CronTime
# 2024-04-17 06:35:00                  4.870495                  4.900904
# 2024-04-17 06:40:00                  4.870702                  4.901652
# 2024-04-17 06:45:00                  4.865686                  4.896168
# 2024-04-17 06:50:00                  4.872447                  4.902898
# 2024-04-17 06:55:00                  4.886872                  4.916951
# ...                                       ...                       ...
# 2025-12-05 13:10:00                  5.003583                  5.037462
# 2025-12-05 13:15:00                  5.026639                  5.059974
# 2025-12-05 13:20:00                  5.044709                  5.077268
# 2025-12-05 13:25:00                  5.046190                  5.079371
# 2025-12-05 13:30:00                  5.049227                  5.081786
#
# [172020 rows x 2 columns]

# %%
df_5min.info()
df_5min.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 172020 entries, 2024-04-17 06:35:00 to 2025-12-05 13:30:00
# Freq: 5min
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   B2_PT1281_DACA_PV__Value  63436 non-null  float64
#  1   B1_PT1281_DACA_PV__Value  63436 non-null  float64
# dtypes: float64(2)
# memory usage: 3.9 MB
#        B2_PT1281_DACA_PV__Value  B1_PT1281_DACA_PV__Value
# count              63436.000000              63436.000000
# mean                   4.720907                  4.256343
# std                    0.673447                  1.659926
# min                   -0.000874                 -0.016891
# 25%                    4.823188                  4.829580
# 50%                    4.892823                  4.903085
# 75%                    4.953421                  4.966776
# max                    5.403195                  5.623745

# %%
df_5min.hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'B2_PT1281_DACA_PV__Value'}>,
#         <Axes: title={'center': 'B1_PT1281_DACA_PV__Value'}>]],
#       dtype=object)

# %%
df_5min = df_5min.clip(lower=0)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df_scaled = pd.DataFrame(
    scaler.fit_transform(df_5min),
    columns=df_5min.columns,
    index=df_5min.index
)

# %%
df_scaled.describe()
# Out:
#        B2_PT1281_DACA_PV__Value  B1_PT1281_DACA_PV__Value
# count              63436.000000              63436.000000
# mean                   0.873725                  0.756853
# std                    0.124639                  0.295161
# min                    0.000000                  0.000000
# 25%                    0.892655                  0.858784
# 50%                    0.905543                  0.871854
# 75%                    0.916758                  0.883179
# max                    1.000000                  1.000000

# %%
df_scaled = df_5min.dropna()

X = df_scaled[["B1_PT1281_DACA_PV__Value"]]
y = df_scaled["B2_PT1281_DACA_PV__Value"]

split_idx = int(len(df_scaled) * 0.8)

X_train = X.iloc[:split_idx]
X_test  = X.iloc[split_idx:]

y_train = y.iloc[:split_idx]
y_test  = y.iloc[split_idx:]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

models = {
    "LinearRegression": LinearRegression(),
    "RandomForest": RandomForestRegressor(
        n_estimators=100, random_state=42
    ),
    "GradientBoosting": GradientBoostingRegressor(random_state=42),
    "SVR": SVR(),
    "XGBoost": XGBRegressor(
        n_estimators=100,
        learning_rate=0.1,
        max_depth=3,
        random_state=42
    ),
}

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

results = []

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred) 

    results.append([name, mae, rmse, r2])

# %%
import pandas as pd

results_df = pd.DataFrame(
    results, columns=["Model", "MAE", "RMSE", "R2"]
)

results_df.sort_values("RMSE")
# Out:
#               Model       MAE      RMSE        R2
# 4           XGBoost  0.410821  1.038596 -0.245282
# 2  GradientBoosting  0.477100  1.108212 -0.417816
# 1      RandomForest  0.530162  1.198989 -0.659605
# 0  LinearRegression  0.700513  1.321088 -1.014827
# 3               SVR  0.706556  1.321885 -1.017259

# %%
best_model = models["XGBoost"] 
y_pred_best = best_model.predict(X_test)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
plt.plot(y_test.index, y_test.values, label="Actual", linewidth=2)
plt.plot(y_test.index, y_pred_best, label="Predicted", linestyle="--")
plt.legend()
plt.title("Superheated Steam Pressure Prediction (5-min)")
plt.xlabel("Time")
plt.ylabel("Normalized Pressure")
plt.show()

# %% [markdown]
# ** DÒNG ĐIỆN LÀM VIỆC QUẠT CẤP 1

# %%
use_cols = [
    "CronTime",
    "B1_S051AIT_DACA_PV__Value",
    "B2_S051AIT_DACA_PV__Value",
]
result = []

for chunk in pd.read_csv(
    r"D:\LDA\LDA---ML--RnD\ai\data\_DCS_Items__202512051333.csv",
    usecols=use_cols,
    chunksize=300_000,
):
    chunk["CronTime"] = pd.to_datetime(chunk["CronTime"])
    chunk = chunk.set_index("CronTime")
    resampled = chunk.resample("5min").mean()
    result.append(resampled)

df_5min = pd.concat(result)

df_5min
# Out:
#                      B1_S051AIT_DACA_PV__Value  B2_S051AIT_DACA_PV__Value
# CronTime
# 2024-04-17 06:35:00                  56.517803                  56.566923
# 2024-04-17 06:40:00                  56.518030                  56.424898
# 2024-04-17 06:45:00                  56.630174                  56.462298
# 2024-04-17 06:50:00                  56.827756                  56.623906
# 2024-04-17 06:55:00                  57.040692                  56.463630
# ...                                        ...                        ...
# 2025-12-05 13:10:00                  61.563110                  56.044920
# 2025-12-05 13:15:00                  61.746680                  56.108360
# 2025-12-05 13:20:00                  61.232700                  55.996510
# 2025-12-05 13:25:00                  61.509715                  56.261955
# 2025-12-05 13:30:00                  61.713300                  56.198520
#
# [172020 rows x 2 columns]

# %%
df_5min.info()
df_5min.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 172020 entries, 2024-04-17 06:35:00 to 2025-12-05 13:30:00
# Freq: 5min
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   B1_S051AIT_DACA_PV__Value  63436 non-null  float64
#  1   B2_S051AIT_DACA_PV__Value  63436 non-null  float64
# dtypes: float64(2)
# memory usage: 3.9 MB
#        B1_S051AIT_DACA_PV__Value  B2_S051AIT_DACA_PV__Value
# count               63436.000000               63436.000000
# mean                   49.636977                  59.279463
# std                    19.569770                   8.369819
# min                     0.000000                   0.000000
# 25%                    55.749050                  57.114739
# 50%                    56.698926                  58.025612
# 75%                    57.580714                  59.500770
# max                    79.971535                  83.544840

# %%
df_5min.hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'B1_S051AIT_DACA_PV__Value'}>,
#         <Axes: title={'center': 'B2_S051AIT_DACA_PV__Value'}>]],
#       dtype=object)

# %%
df_scaled = df_5min.dropna()

X = df_scaled[["B1_S051AIT_DACA_PV__Value"]]
y = df_scaled["B2_S051AIT_DACA_PV__Value"]

split_idx = int(len(df_scaled) * 0.8)

X_train = X.iloc[:split_idx]
X_test  = X.iloc[split_idx:]

y_train = y.iloc[:split_idx]
y_test  = y.iloc[split_idx:]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

models = {
    "LinearRegression": LinearRegression(),
    "RandomForest": RandomForestRegressor(
        n_estimators=100, random_state=42
    ),
    "GradientBoosting": GradientBoostingRegressor(random_state=42),
    "SVR": SVR(),
    "XGBoost": XGBRegressor(
        n_estimators=100,
        learning_rate=0.1,
        max_depth=3,
        random_state=42
    ),
}

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

results = []

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred) 

    results.append([name, mae, rmse, r2])

# %%
import pandas as pd

results_df = pd.DataFrame(
    results, columns=["Model", "MAE", "RMSE", "R2"]
)

results_df.sort_values("RMSE")
# Out:
#               Model       MAE       RMSE        R2
# 3               SVR  7.663385  12.179559  0.328016
# 0  LinearRegression  8.511383  13.526036  0.171225
# 4           XGBoost  8.281718  13.740763  0.144702
# 2  GradientBoosting  8.748553  15.268925 -0.056118
# 1      RandomForest  9.534350  15.785728 -0.128820

# %%
best_model = models["SVR"] 
y_pred_best = best_model.predict(X_test)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
plt.plot(y_test.index, y_test.values, label="Actual", linewidth=2)
plt.plot(y_test.index, y_pred_best, label="Predicted", linestyle="--")
plt.legend()
plt.title("Superheated Steam Pressure Prediction (5-min)")
plt.xlabel("Time")
plt.ylabel("Normalized Pressure")
plt.show()

# %% [markdown]
# **DÒNG ĐIỆN LÀM VIỆC QUẠT CẤP 2

# %%
use_cols = [
    "CronTime",
    "B1_S052AIT_DACA_PV__Value",
    "B2_S052AIT_DACA_PV__Value",
]
result = []

for chunk in pd.read_csv(
    r"D:\LDA\LDA---ML--RnD\ai\data\_DCS_Items__202512051333.csv",
    usecols=use_cols,
    chunksize=300_000,
):
    chunk["CronTime"] = pd.to_datetime(chunk["CronTime"])
    chunk = chunk.set_index("CronTime")
    resampled = chunk.resample("5min").mean()
    result.append(resampled)

df_5min = pd.concat(result)

df_5min
# Out:
#                      B2_S052AIT_DACA_PV__Value  B1_S052AIT_DACA_PV__Value
# CronTime
# 2024-04-17 06:35:00                   3.340472                   3.302444
# 2024-04-17 06:40:00                   3.416452                   3.381359
# 2024-04-17 06:45:00                   3.563813                   3.507741
# 2024-04-17 06:50:00                   3.557135                   3.516197
# 2024-04-17 06:55:00                   3.566484                   3.525986
# ...                                        ...                        ...
# 2025-12-05 13:10:00                   3.687355                   4.038194
# 2025-12-05 13:15:00                   3.677338                   4.064894
# 2025-12-05 13:20:00                   3.741893                   4.106058
# 2025-12-05 13:25:00                   3.700711                   4.067120
# 2025-12-05 13:30:00                   3.708503                   4.080472
#
# [172020 rows x 2 columns]

# %%
df_5min.info()
df_5min.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 172020 entries, 2024-04-17 06:35:00 to 2025-12-05 13:30:00
# Freq: 5min
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   B2_S052AIT_DACA_PV__Value  63436 non-null  float64
#  1   B1_S052AIT_DACA_PV__Value  63436 non-null  float64
# dtypes: float64(2)
# memory usage: 3.9 MB
#        B2_S052AIT_DACA_PV__Value  B1_S052AIT_DACA_PV__Value
# count               63436.000000               63436.000000
# mean                    7.072309                   3.044604
# std                     7.925923                   2.109471
# min                     0.000000                   0.000000
# 25%                     3.571826                   2.819755
# 50%                     3.848740                   3.140163
# 75%                     4.428667                   3.430310
# max                    39.296555                  57.299285

# %%
df_5min.hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'B2_S052AIT_DACA_PV__Value'}>,
#         <Axes: title={'center': 'B1_S052AIT_DACA_PV__Value'}>]],
#       dtype=object)

# %%
df_scaled = df_5min.dropna()

X = df_scaled[["B1_S052AIT_DACA_PV__Value"]]
y = df_scaled["B2_S052AIT_DACA_PV__Value"]

split_idx = int(len(df_scaled) * 0.8)

X_train = X.iloc[:split_idx]
X_test  = X.iloc[split_idx:]

y_train = y.iloc[:split_idx]
y_test  = y.iloc[split_idx:]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

models = {
    "LinearRegression": LinearRegression(),
    "RandomForest": RandomForestRegressor(
        n_estimators=100, random_state=42
    ),
    "GradientBoosting": GradientBoostingRegressor(random_state=42),
    "SVR": SVR(),
    "XGBoost": XGBRegressor(
        n_estimators=100,
        learning_rate=0.1,
        max_depth=3,
        random_state=42
    ),
}

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

results = []

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred) 

    results.append([name, mae, rmse, r2])

# %%
import pandas as pd

results_df = pd.DataFrame(
    results, columns=["Model", "MAE", "RMSE", "R2"]
)

results_df.sort_values("RMSE")
# Out:
#               Model        MAE       RMSE        R2
# 4           XGBoost   6.642256   9.234002  0.388946
# 3               SVR   6.970455   9.368356  0.371035
# 2  GradientBoosting   7.627794  10.320749  0.236653
# 1      RandomForest   7.722252  10.411203  0.223214
# 0  LinearRegression  14.006245  21.000363 -2.160481

# %%
best_model = models["XGBoost"] 
y_pred_best = best_model.predict(X_test)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15,5))
plt.plot(y_test.index, y_test.values, label="Actual", linewidth=2)
plt.plot(y_test.index, y_pred_best, label="Predicted", linestyle="--")
plt.legend()
plt.title("Superheated Steam Pressure Prediction (5-min)")
plt.xlabel("Time")
plt.ylabel("Normalized Pressure")
plt.show()
